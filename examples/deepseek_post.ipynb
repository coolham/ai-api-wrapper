# %%
import sys
from dotenv import load_dotenv, find_dotenv

sys.path.append('../../ai_api_wrapper')
load_dotenv(find_dotenv())
# Out:
# True

# %%
import ai_api_wrapper as ai

client = ai.Client()
messages = [
    {"role": "system", "content": "Talk using Pirate English."},
    {"role": "user", "content": "Tell me a joke in 1 line."},
]

# %%
response = client.chat.completions.create(model="deepseek:deepseek-reasoner", messages=messages, temperature=0.75)
print(f"Content:\n{response.choices[0].message.content}\n\nReasoning content:\n{response.choices[0].message.reasoning_content}")
# Out:
# Content:
# Arrr, why don't pirates shower? They just wash up on shore!
#
# Reasoning content:
# Alright, let's tackle this query. The user wants a joke in one line using Pirate English. First, I need to recall some pirate terminology and slang. Words like "arrr," "matey," "treasure," "parrot," "peg-leg," "aye," "yo-ho-ho," and phrases typical of pirate speak.
#
# Next, I need to think of a simple joke structure. Puns are often effective. The classic "Why did the pirate..." setup comes to mind. Common pirate elements include the parrot, treasure, ship, and maybe something like a hook or a peg-leg.
#
# Combining a pun with a pirate element. The parrot joke is a classic: "Why did the pirate get a parrot? Because he wanted aaaarrr matey!" Here, "arrr" sounds like "R," playing on the pirate's accent. But wait, "aaarrr matey" is the pirate's way of saying "R, matey," but the joke is that the parrot is for the "aaarrr" sound. Alternatively, maybe a play on "pieces of eight" or something related to treasure.
#
# Wait, another possibility: "Why don't pirates take a bath before walking the plank? Because they'll just wash up on shore later!" But that's two lines. Need to keep it one line.
#
# Original idea: Maybe "Why don't pirates shower? They just wash up on shore!" But that's a play on "wash up" meaning both cleaning and being carried by the waves. But does that work in pirate speak? Maybe "Why don't pirates bathe afore walkin' the plank? They'll just wash up on shore!" Still two lines.
#
# Alternatively, stick with the parrot joke. "Why did the pirate buy a parrot? To teach it the 'Pieces of Eight'!" Hmm, but "pieces of eight" is more about treasure. Maybe not as funny.
#
# The original "Why did the pirate get a parrot? Because he wanted aaaarrr matey!" is concise and works as a one-liner. The pun is on "R" (as in the letter) sounding like "arrr," which is a common pirate exclamation. The humor comes from the wordplay and the pirate's accent.
#
# Need to ensure the pirate English is properly applied. Replace "you" with "ye," "my" with "me," use "matey," "aye," "yo-ho-ho," etc. So adjusting the joke: "Arrr, why did the pirate adopt a parrot? To squawk 'Pieces o' eight' and keep his doubloons company!" But that's a bit long.
#
# Alternatively, "Why be pirates bad at cards? 'Cause they always stand on the deck!" But that's a different joke.
#
# Sticking to the original idea, but ensuring pirate lingo. Maybe "Arrr, why'd the pirate get a parrot? To squawk 'Walk the plank, matey!'" Not as strong.
#
# The first version seems best. Let's check the pirate terms again. "Arrr," "matey," "aye," "yo-ho-ho," "doubloons," "pieces of eight," "ahoy," "avast," "scallywag," "savvy," "shiver me timbers," "Jolly Roger," "plank," "landlubber," "booty," "treasure," "helm," "swashbuckling," "peg-leg," "hook," "parrot," "cannon," "rum," "grog," "sloop," "brigantine," "mizzenmast," "yo-ho-ho."
#
# So, the joke: "Why did the pirate buy a parrot? 'Cause he wanted someone to yell 'Aaarrr!' when he walked into a room!" But that's two lines. Need one line.
#
# Original thought: "Arrr, why did the pirate get a parrot? To teach it the 'Aaarrr' of the law!" No, maybe not.
#
# Wait, the classic one-liner is: "Why don't pirates take a bath? Because they'll just wash up on shore later!" But in pirate speak: "Arrr, why don't pirates bathe? They'll just wash ashore, matey!" Still two lines.
#
# Alternatively, "What's a pirate's favorite letter? Ye think it be the 'R,' but it be the 'C'!" But that's two lines. The user wants one line.
#
# Hmm. Maybe condense it. The classic answer is "Arrr, but their first love be the C (sea)." But again, two lines.
#
# Wait, the original joke is "Why did the pirate get a parrot? Because he wanted aaaarrr matey!" That's one line if phrased correctly. Let me check: "Arrr, why'd the pirate adopt a parrot? To squawk 'Aaarrr, matey!'" That's one line.
#
# Alternatively, "Why do pirates hate the alphabet? They get lost at 'C' (sea)!" Again, two lines.
#
# The best one-line pirate joke that's concise and uses pirate English is likely the parrot one. So the final answer would be: "Arrr, why did the pirate buy a parrot? 'Cause it yelled 'Pieces o' eight' every time he opened his treasure chest!" But that's two lines.
#
# Wait, the user wants the joke in one line. So perhaps: "Arrr, why'd the pirate get a parrot? To teach it the 'Aaarrr' of the law!" No, that doesn't make sense.
#
# Wait, the classic joke is "What's a pirate's favorite letter? R!" But in pirate speak: "Arrr, a pirate's favorite letter be the 'R'!" But that's not a joke.
#
# Alternatively, "Why don't pirates shower before walking the plank? They'll wash up on shore anyway!" But again, two lines.
#
# I think the best one-liner in pirate English is the parrot pun. So the answer is: "Arrr, why did the pirate get a parrot? To squawk 'Aaarrr, matey!' every time he found treasure!" But still two parts.
#
# Wait, perhaps: "Arrr, a pirate's parrot be squawkin' 'Aaarrr' 'cause it's the only letter he knows!" Hmm, not great.
#
# Alternatively, "Arrr, what's a pirate's favorite letter? 'Tis the 'C' they love sailin'!" Still two lines.
#
# Maybe the user is okay with a setup and punchline in one line. For example: "Why did the pirate buy a parrot? To teach it to say 'Aaarrr, matey!'" But that's two clauses.
#
# In pirate English, perhaps: "Arrr, why'd a pirate adopt a parrot? To holler 'Aaarrr' every mornin'!" Still two parts.
#
# Alternatively, condense into one line without a question: "A pirate's parrot be always squawkin' 'Aaarrr' 'cause it's the only letter he knows!" Maybe.
#
# Alternatively, use a different joke structure. "A pirate's favorite letter be 'Arrr,' but his first love be the 'C' (sea)!" But again, two lines.
#
# Hmm, this is tricky. The user wants one line. Let's check the example. The assistant previously used: "Arrr, why did the pirate buy a parrot? 'Cause he needed a matey to squawk 'Pieces o' eight' when he found treasure!" But that's two lines.
#
# Wait, maybe the user is okay with a one-line joke that's a single sentence. For example: "Arrr, a pirate’s parrot be the best at yellin’ ‘Aaarrr’ every time he spots land!" But not really a joke.
#
# Wait, here's an idea: "Why be pirates terrible at cards? They always stand on the deck!" That's a play on "deck" as both ship deck and card deck. But does it work in pirate English? "Arrr, pirates be terrible at cards 'cause they always stand on the deck!" That's one line.
#
# But is that a common joke? Maybe not as much as the parrot one.
#
# Alternatively, "Why did the pirate go to school? To improve his 'Aaarrr'-ithmetic!" Pun on arithmetic. But in pirate speak: "Arrr, the pirate went to school to master 'Aaarrr'-ithmetic!" One line.
#
# That's a good pun. Combines "arrr" with "arithmetic."
#
# So the final answer could be: "Arrr, why did the pirate go to school? To get better at 'Aaarrr'-ithmetic!"
#
# But the user requested one line. So maybe: "A pirate went to school to master 'Aaarrr'-ithmetic!" But that's not a joke structure.
#
# Alternatively, "Why'd the pirate study math? For his 'Aaarrr'-ithmetic!" Still two parts.
#
# Hmm. The original parrot joke seems the most straightforward. Maybe the assistant's initial thought is acceptable.
#
# So, the answer is: "Arrr, why did the pirate get a parrot? 'Twas cheaper than a crew to shout 'Land ho!'" But that's two lines.
#
# Alternatively, "A pirate's parrot be cheaper than a crew to shout 'Land ho!'" Not a joke.
#
# Wait, perhaps the classic: "Why don't pirates take a bath? They just wash up on shore!" In pirate English: "Arrr, pirates skip baths 'cause they'll wash ashore anyhow!" One line.
#
# Yes, that works. Combines the joke into a single line with pirate lingo.
#
# So the final answer: "Arrr, pirates skip baths 'cause they’ll wash ashore anyhow, savvy?"
#
# But maybe better as: "Arrr, pirates don't bathe—they just wash up on shore!"
#
# Yes, that's one line. It's a play on "wash up" meaning both bathing and being carried to shore by the waves.
#
# That's concise and fits the pirate theme. So the joke is: "Arrr, pirates don't bathe—they just wash up on shore!"
#
# But does that make sense? If they don't bathe, they'd be dirty, but the joke is that when they die (walk the plank), they wash up on shore. But maybe the user will get it.
#
# Alternatively, "Arrr, why don't pirates shower? They’ll wash up on shore later!"
#
# But again, in one line.
#
# Yes, the best one-line pirate joke is: "Arrr, pirates don't bathe—they just wash up on shore!"
#
# That's concise, uses pirate English, and is a play on words.
#
# Alternatively, the parrot joke: "Arrr, a pirate’s parrot be yellin' 'Aaarrr' ‘cause it’s the only letter he knows!"
#
# But the bathing joke is better.
#
# I think the bathing joke is more likely to be understood. So final decision: "Arrr, pirates don't bathe—they just wash up on shore!"

# %%
response = client.chat.completions.create(model="sambanova:DeepSeek-R1-Distill-Llama-70B", messages=messages, temperature=0.75)
print(f"Content:\n{response.choices[0].message.content}\n\nReasoning content:\n{response.choices[0].message.reasoning_content}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 response = client.chat.completions.create(model="sambanova:DeepSeek-R1-Distill-Llama-70B", messages=messages, temperature=0.75)
#       2 print(f"Content:\n{response.choices[0].message.content}\n\nReasoning content:\n{response.choices[0].message.reasoning_content}")
#
# File ~/Projects/ai_projects/ai-api-wrapper/ai_api_wrapper/client.py:221, in Completions.create(self, model, messages, **kwargs)
#     219 if provider_key not in self.client.providers:
#     220     config = self.client.provider_configs.get(provider_key, {})
# --> 221     self.client.providers[provider_key] = ProviderFactory.create_provider(
#     222         provider_key, config
#     223     )
#     225 provider = self.client.providers.get(provider_key)
#     226 if not provider:
#
# File ~/Projects/ai_projects/ai-api-wrapper/ai_api_wrapper/provider.py:46, in ProviderFactory.create_provider(cls, provider_key, config)
#      44 # Instantiate the provider class
#      45 provider_class = getattr(module, provider_class_name)
# ---> 46 return provider_class(**config)
#
# File ~/Projects/ai_projects/ai-api-wrapper/ai_api_wrapper/providers/sambanova_provider.py:28, in SambanovaProvider.__init__(self, **config)
#      26 self.api_key = config.get("api_key", os.getenv("SAMBANOVA_API_KEY"))
#      27 if not self.api_key:
# ---> 28     raise ValueError(
#      29         "Sambanova API key is missing. Please provide it in the config or set the SAMBANOVA_API_KEY environment variable."
#      30     )
#      32 config["api_key"] = self.api_key
#      33 config["base_url"] = "https://api.sambanova.ai/v1/"
#
# ValueError: Sambanova API key is missing. Please provide it in the config or set the SAMBANOVA_API_KEY environment variable.
